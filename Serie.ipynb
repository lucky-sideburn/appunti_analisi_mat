# %%
import matplotlib.pyplot as plt

import numpy as np

from scipy import optimize

from scipy import misc

from scipy import integrate

from sympy import limit, Symbol

import sympy as sp

# %%
def f(x):
    return x

# %%
indice = input("Inserisci indice  ")
intervallo = input("Inserisci intervallo  ")
funzione = input("Inserisci funzione  ")
# Out:
# Inserisci indice  0
# Inserisci intervallo  10
# Inserisci funzione  x ^ 2

# %%
sum(funzione for i in (indice..intervallo))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/kt/t0ps2g_15r38z_xxsctl0b9r0000gn/T/ipykernel_61084/1003999779.py in <module>
# ----> 1 sum(funzione for i in (ellipsis_iter(indice,Ellipsis,intervallo)))
#
# /private/var/tmp/sage-9.6-current/local/var/lib/sage/venv-python3.10.3/lib/python3.10/site-packages/sage/misc/functional.py in symbolic_sum(expression, *args, **kwds)
#     574         return expression.sum(*args, **kwds)
#     575     elif len(args) <= 1:
# --> 576         return sum(expression, *args)
#     577     else:
#     578         from sage.symbolic.ring import SR
#
# /var/folders/kt/t0ps2g_15r38z_xxsctl0b9r0000gn/T/ipykernel_61084/1003999779.py in <genexpr>(.0)
# ----> 1 sum(funzione for i in (ellipsis_iter(indice,Ellipsis,intervallo)))
#
# /private/var/tmp/sage-9.6-current/local/var/lib/sage/venv-python3.10.3/lib/python3.10/site-packages/sage/arith/srange.pyx in ellipsis_iter (build/cythonized/sage/arith/srange.c:5732)()
#     425             more = xsrange(start, end, step, coerce=False, include_endpoint=True)
#     426             try:
# --> 427                 first = next(more)
#     428                 if last_end != first:
#     429                     yield first
#
# /private/var/tmp/sage-9.6-current/local/var/lib/sage/venv-python3.10.3/lib/python3.10/site-packages/sage/arith/srange.pyx in xsrange (build/cythonized/sage/arith/srange.c:3517)()
#     121         raise ValueError("step argument must not be zero")
#     122
# --> 123     count = (end - start) / step
#     124
#     125     # If count is exact, set endpoint_tolerance to zero
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
